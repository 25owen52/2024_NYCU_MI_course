# %% [markdown]
# ## Data Preparation

# %%
# install scikit-learn, tensorflow, pandas, matplotlib, numpy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# randomseed
np.random.seed(0)

# data : y = ax+b
a = 2
b = 1
noise_scale = 10

# data generation
x = np.linspace(0, 50, 100)
q = np.random.normal(0, noise_scale, x.shape)
y = a * x + b + q

# # data : y = a*exp(bx)
# a = 2
# b = 1
# c= 50
# noise_scale = 20

# # data generation
# x = np.linspace(0, 5, 100)
# y = a * np.exp(b * x) + q + c

# splitting dataset to training set and testing set 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ##  Data visualization

# %%
plt.scatter(x_train, y_train, color='blue', label='Training data')
plt.scatter(x_test, y_test, color='red', label='Testing data')
plt.legend()
plt.show()

# %% [markdown]
# ## Build ANN model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

model = Sequential([
    Dense(1, input_shape=(1,), activation='linear')
])

# model = Sequential([
#     Dense(5, input_shape=(1,), activation='relu'),
#     Dense(3, activation='relu'),
#     Dense(1, activation='linear')
# ])

# Sequential.help
model.compile(optimizer=Adam(learning_rate=0.01), loss='mse')

# %% [markdown]
# ## Training ANN model

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)
history = model.fit(x_train, y_train, validation_split=0.2, epochs=200, batch_size=2)
# Out:
# Epoch 1/200
# 32/32 [==============================] - 1s 7ms/step - loss: 4643.8379 - val_loss: 4649.0171
# Epoch 2/200
# 32/32 [==============================] - 0s 2ms/step - loss: 3660.1589 - val_loss: 3647.8904
# Epoch 3/200
# 32/32 [==============================] - 0s 2ms/step - loss: 2860.0854 - val_loss: 2831.1440
# Epoch 4/200
# 32/32 [==============================] - 0s 2ms/step - loss: 2196.6577 - val_loss: 2173.6113
# Epoch 5/200
# 32/32 [==============================] - 0s 2ms/step - loss: 1671.2976 - val_loss: 1639.9646
# Epoch 6/200
# 32/32 [==============================] - 0s 2ms/step - loss: 1254.1638 - val_loss: 1218.2612
# Epoch 7/200
# 32/32 [==============================] - 0s 2ms/step - loss: 931.7404 - val_loss: 897.2312
# Epoch 8/200
# 32/32 [==============================] - 0s 2ms/step - loss: 691.1489 - val_loss: 652.3330
# Epoch 9/200
# 32/32 [==============================] - 0s 2ms/step - loss: 505.3993 - val_loss: 488.4666
# Epoch 10/200
# 32/32 [==============================] - 0s 2ms/step - loss: 381.4468 - val_loss: 354.7823
# Epoch 11/200
# 32/32 [==============================] - 0s 2ms/step - loss: 285.6351 - val_loss: 267.7028
# Epoch 12/200
# 32/32 [==============================] - 0s 2ms/step - loss: 222.1832 - val_loss: 207.3857
# Epoch 13/200
# 32/32 [==============================] - 0s 3ms/step - loss: 179.2044 - val_loss: 163.8275
# Epoch 14/200
# 32/32 [==============================] - 0s 2ms/step - loss: 151.9613 - val_loss: 132.2161
# Epoch 15/200
# 32/32 [==============================] - 0s 2ms/step - loss: 132.2964 - val_loss: 115.8678
# Epoch 16/200
# 32/32 [==============================] - 0s 2ms/step - loss: 121.3553 - val_loss: 103.8744
# Epoch 17/200
# 32/32 [==============================] - 0s 2ms/step - loss: 114.3625 - val_loss: 94.9695
# Epoch 18/200
# 32/32 [==============================] - 0s 2ms/step - loss: 110.2943 - val_loss: 89.6987
# Epoch 19/200
# 32/32 [==============================] - 0s 2ms/step - loss: 107.6241 - val_loss: 87.0719
# Epoch 20/200
# 32/32 [==============================] - 0s 2ms/step - loss: 106.3636 - val_loss: 85.0091
# Epoch 21/200
# 32/32 [==============================] - 0s 2ms/step - loss: 106.4790 - val_loss: 83.1144
# Epoch 22/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.5236 - val_loss: 83.4305
# Epoch 23/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.3935 - val_loss: 82.2056
# Epoch 24/200
# 32/32 [==============================] - 0s 2ms/step - loss: 104.9514 - val_loss: 81.8918
# Epoch 25/200
# 32/32 [==============================] - 0s 2ms/step - loss: 104.9305 - val_loss: 81.7232
# Epoch 26/200
# 32/32 [==============================] - 0s 2ms/step - loss: 104.9920 - val_loss: 81.6845
# Epoch 27/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.0347 - val_loss: 81.0141
# Epoch 28/200
# 32/32 [==============================] - 0s 2ms/step - loss: 104.7354 - val_loss: 81.3224
# Epoch 29/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.1988 - val_loss: 80.9932
# Epoch 30/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.3776 - val_loss: 82.0242
# Epoch 31/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.3656 - val_loss: 80.7324
# Epoch 32/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.2932 - val_loss: 81.7084
# Epoch 33/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.3843 - val_loss: 80.8319
# Epoch 34/200
# 32/32 [==============================] - 0s 2ms/step - loss: 104.9080 - val_loss: 80.9442
# Epoch 35/200
# 32/32 [==============================] - 0s 2ms/step - loss: 104.9528 - val_loss: 81.0760
# Epoch 36/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.1509 - val_loss: 81.4898
# Epoch 37/200
# 32/32 [==============================] - 0s 2ms/step - loss: 104.9434 - val_loss: 81.0730
# Epoch 38/200
# 32/32 [==============================] - 0s 2ms/step - loss: 104.9364 - val_loss: 81.0340
# Epoch 39/200
# 32/32 [==============================] - 0s 3ms/step - loss: 104.7728 - val_loss: 81.1232
# Epoch 40/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.0036 - val_loss: 81.3032
# Epoch 41/200
# 32/32 [==============================] - 0s 2ms/step - loss: 104.8372 - val_loss: 81.0157
# Epoch 42/200
# 32/32 [==============================] - 0s 2ms/step - loss: 104.9338 - val_loss: 81.3867
# Epoch 43/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.0892 - val_loss: 81.2866
# Epoch 44/200
# 32/32 [==============================] - 0s 2ms/step - loss: 104.9984 - val_loss: 80.9883
# Epoch 45/200
# 32/32 [==============================] - 0s 2ms/step - loss: 104.8958 - val_loss: 81.2465
# Epoch 46/200
# 32/32 [==============================] - 0s 2ms/step - loss: 104.8515 - val_loss: 81.1062
# Epoch 47/200
# 32/32 [==============================] - 0s 2ms/step - loss: 104.9603 - val_loss: 80.9263
# Epoch 48/200
# 32/32 [==============================] - 0s 2ms/step - loss: 104.9795 - val_loss: 81.3622
# Epoch 49/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.0584 - val_loss: 81.2647
# Epoch 50/200
# 32/32 [==============================] - 0s 2ms/step - loss: 104.9236 - val_loss: 80.8041
# Epoch 51/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.3477 - val_loss: 81.4902
# Epoch 52/200
# 32/32 [==============================] - 0s 2ms/step - loss: 104.6713 - val_loss: 80.7753
# Epoch 53/200
# 32/32 [==============================] - 0s 2ms/step - loss: 104.9792 - val_loss: 80.9181
# Epoch 54/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.0840 - val_loss: 81.2619
# Epoch 55/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.9446 - val_loss: 81.2198
# Epoch 56/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.1137 - val_loss: 80.6157
# Epoch 57/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.1545 - val_loss: 80.7687
# Epoch 58/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.1489 - val_loss: 81.1925
# Epoch 59/200
# 32/32 [==============================] - 0s 2ms/step - loss: 104.8839 - val_loss: 81.0417
# Epoch 60/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.3832 - val_loss: 80.7390
# Epoch 61/200
# 32/32 [==============================] - 0s 2ms/step - loss: 104.8846 - val_loss: 81.6425
# Epoch 62/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.3053 - val_loss: 80.9857
# Epoch 63/200
# 32/32 [==============================] - 0s 2ms/step - loss: 104.8505 - val_loss: 81.0415
# Epoch 64/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.0683 - val_loss: 81.2893
# Epoch 65/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.2985 - val_loss: 80.9625
# Epoch 66/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.0675 - val_loss: 80.7457
# Epoch 67/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.3650 - val_loss: 80.5773
# Epoch 68/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.6510 - val_loss: 81.0091
# Epoch 69/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.3331 - val_loss: 80.6257
# Epoch 70/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.0344 - val_loss: 81.1285
# Epoch 71/200
# 32/32 [==============================] - 0s 2ms/step - loss: 104.9548 - val_loss: 81.2530
# Epoch 72/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.5621 - val_loss: 80.4431
# Epoch 73/200
# 32/32 [==============================] - 0s 3ms/step - loss: 105.0128 - val_loss: 81.0631
# Epoch 74/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.2287 - val_loss: 81.7006
# Epoch 75/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.1806 - val_loss: 81.4234
# Epoch 76/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.0464 - val_loss: 80.8391
# Epoch 77/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.1458 - val_loss: 80.7106
# Epoch 78/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.0005 - val_loss: 81.2998
# Epoch 79/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.0173 - val_loss: 80.6538
# Epoch 80/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.1901 - val_loss: 80.4200
# Epoch 81/200
# 32/32 [==============================] - 0s 2ms/step - loss: 104.9532 - val_loss: 80.9667
# Epoch 82/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.2456 - val_loss: 81.3555
# Epoch 83/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.7342 - val_loss: 80.9174
# Epoch 84/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.1956 - val_loss: 81.9818
# Epoch 85/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.1002 - val_loss: 80.6881
# Epoch 86/200
# 32/32 [==============================] - 0s 2ms/step - loss: 106.1663 - val_loss: 80.3166
# Epoch 87/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.0906 - val_loss: 81.4669
# Epoch 88/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.5235 - val_loss: 80.5813
# Epoch 89/200
# 32/32 [==============================] - 0s 2ms/step - loss: 106.0574 - val_loss: 80.7755
# Epoch 90/200
# 32/32 [==============================] - 0s 2ms/step - loss: 106.5463 - val_loss: 82.2651
# Epoch 91/200
# 32/32 [==============================] - 0s 2ms/step - loss: 104.8700 - val_loss: 80.4945
# Epoch 92/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.0593 - val_loss: 80.4410
# Epoch 93/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.6599 - val_loss: 81.7408
# Epoch 94/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.1127 - val_loss: 80.9216
# Epoch 95/200
# 32/32 [==============================] - 0s 2ms/step - loss: 106.3021 - val_loss: 79.9946
# Epoch 96/200
# 32/32 [==============================] - 0s 2ms/step - loss: 106.4095 - val_loss: 81.8073
# Epoch 97/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.1500 - val_loss: 80.7145
# Epoch 98/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.9327 - val_loss: 80.9494
# Epoch 99/200
# 32/32 [==============================] - 0s 2ms/step - loss: 106.2796 - val_loss: 79.7889
# Epoch 100/200
# 32/32 [==============================] - 0s 2ms/step - loss: 106.3524 - val_loss: 80.3287
# Epoch 101/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.8830 - val_loss: 82.3215
# Epoch 102/200
# 32/32 [==============================] - 0s 2ms/step - loss: 104.8934 - val_loss: 81.2973
# Epoch 103/200
# 32/32 [==============================] - 0s 2ms/step - loss: 104.8027 - val_loss: 79.9671
# Epoch 104/200
# 32/32 [==============================] - 0s 2ms/step - loss: 106.7000 - val_loss: 81.3860
# Epoch 105/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.1875 - val_loss: 79.7158
# Epoch 106/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.2867 - val_loss: 80.4165
# Epoch 107/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.1045 - val_loss: 81.1790
# Epoch 108/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.9291 - val_loss: 82.4002
# Epoch 109/200
# 32/32 [==============================] - 0s 2ms/step - loss: 106.2419 - val_loss: 79.8702
# Epoch 110/200
# 32/32 [==============================] - 0s 2ms/step - loss: 104.9477 - val_loss: 80.7283
# Epoch 111/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.1929 - val_loss: 81.1457
# Epoch 112/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.3685 - val_loss: 80.5727
# Epoch 113/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.6249 - val_loss: 81.7864
# Epoch 114/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.8133 - val_loss: 80.1931
# Epoch 115/200
# 32/32 [==============================] - 0s 2ms/step - loss: 104.8690 - val_loss: 80.6239
# Epoch 116/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.7486 - val_loss: 80.4265
# Epoch 117/200
# 32/32 [==============================] - 0s 2ms/step - loss: 106.3972 - val_loss: 80.9140
# Epoch 118/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.9593 - val_loss: 80.0878
# Epoch 119/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.4562 - val_loss: 80.0481
# Epoch 120/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.7954 - val_loss: 81.3992
# Epoch 121/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.0080 - val_loss: 80.7187
# Epoch 122/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.0067 - val_loss: 79.9426
# Epoch 123/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.3606 - val_loss: 80.4955
# Epoch 124/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.3644 - val_loss: 80.3691
# Epoch 125/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.4538 - val_loss: 80.6965
# Epoch 126/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.1350 - val_loss: 80.8037
# Epoch 127/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.2415 - val_loss: 80.6849
# Epoch 128/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.2169 - val_loss: 80.9341
# Epoch 129/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.7061 - val_loss: 80.4933
# Epoch 130/200
# 32/32 [==============================] - 0s 2ms/step - loss: 107.3049 - val_loss: 79.9260
# Epoch 131/200
# 32/32 [==============================] - 0s 2ms/step - loss: 110.1907 - val_loss: 82.9782
# Epoch 132/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.3885 - val_loss: 79.9169
# Epoch 133/200
# 32/32 [==============================] - 0s 2ms/step - loss: 106.3832 - val_loss: 80.2970
# Epoch 134/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.0763 - val_loss: 80.7369
# Epoch 135/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.9304 - val_loss: 80.1490
# Epoch 136/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.9771 - val_loss: 79.8814
# Epoch 137/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.0919 - val_loss: 80.2208
# Epoch 138/200
# 32/32 [==============================] - 0s 2ms/step - loss: 106.7817 - val_loss: 81.8505
# Epoch 139/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.6112 - val_loss: 79.9512
# Epoch 140/200
# 32/32 [==============================] - 0s 2ms/step - loss: 106.2652 - val_loss: 81.6032
# Epoch 141/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.6896 - val_loss: 80.4793
# Epoch 142/200
# 32/32 [==============================] - 0s 2ms/step - loss: 104.8140 - val_loss: 79.9455
# Epoch 143/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.3650 - val_loss: 80.1509
# Epoch 144/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.4619 - val_loss: 80.8660
# Epoch 145/200
# 32/32 [==============================] - 0s 2ms/step - loss: 107.6577 - val_loss: 80.1280
# Epoch 146/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.3070 - val_loss: 80.8448
# Epoch 147/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.1451 - val_loss: 82.0881
# Epoch 148/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.2262 - val_loss: 80.9877
# Epoch 149/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.2253 - val_loss: 79.7520
# Epoch 150/200
# 32/32 [==============================] - 0s 3ms/step - loss: 105.5200 - val_loss: 80.0802
# Epoch 151/200
# 32/32 [==============================] - 0s 2ms/step - loss: 106.2266 - val_loss: 80.0014
# Epoch 152/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.9580 - val_loss: 80.1569
# Epoch 153/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.6146 - val_loss: 80.1244
# Epoch 154/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.4210 - val_loss: 80.6303
# Epoch 155/200
# 32/32 [==============================] - 0s 2ms/step - loss: 106.9299 - val_loss: 79.5075
# Epoch 156/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.3047 - val_loss: 81.8258
# Epoch 157/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.4344 - val_loss: 80.7453
# Epoch 158/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.4442 - val_loss: 79.7846
# Epoch 159/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.6931 - val_loss: 79.9880
# Epoch 160/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.2046 - val_loss: 80.2801
# Epoch 161/200
# 32/32 [==============================] - 0s 2ms/step - loss: 106.2954 - val_loss: 81.2994
# Epoch 162/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.1299 - val_loss: 80.0210
# Epoch 163/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.0510 - val_loss: 79.8731
# Epoch 164/200
# 32/32 [==============================] - 0s 2ms/step - loss: 106.7762 - val_loss: 79.7690
# Epoch 165/200
# 32/32 [==============================] - 0s 2ms/step - loss: 106.1625 - val_loss: 82.0930
# Epoch 166/200
# 32/32 [==============================] - 0s 2ms/step - loss: 106.3340 - val_loss: 80.3011
# Epoch 167/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.2078 - val_loss: 79.9527
# Epoch 168/200
# 32/32 [==============================] - 0s 2ms/step - loss: 106.5295 - val_loss: 79.6509
# Epoch 169/200
# 32/32 [==============================] - 0s 2ms/step - loss: 104.6609 - val_loss: 81.8391
# Epoch 170/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.4379 - val_loss: 80.6465
# Epoch 171/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.4520 - val_loss: 80.5543
# Epoch 172/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.1551 - val_loss: 80.7287
# Epoch 173/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.6585 - val_loss: 80.0194
# Epoch 174/200
# 32/32 [==============================] - 0s 2ms/step - loss: 106.0383 - val_loss: 81.5573
# Epoch 175/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.5948 - val_loss: 80.3916
# Epoch 176/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.7137 - val_loss: 79.3925
# Epoch 177/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.9838 - val_loss: 80.7932
# Epoch 178/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.7491 - val_loss: 81.2585
# Epoch 179/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.9480 - val_loss: 79.4520
# Epoch 180/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.9311 - val_loss: 80.1090
# Epoch 181/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.4573 - val_loss: 80.8020
# Epoch 182/200
# 32/32 [==============================] - 0s 2ms/step - loss: 106.3672 - val_loss: 81.5598
# Epoch 183/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.3246 - val_loss: 80.9215
# Epoch 184/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.8145 - val_loss: 79.7265
# Epoch 185/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.0682 - val_loss: 80.3493
# Epoch 186/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.9155 - val_loss: 81.9656
# Epoch 187/200
# 32/32 [==============================] - 0s 2ms/step - loss: 106.2077 - val_loss: 80.2384
# Epoch 188/200
# 32/32 [==============================] - 0s 2ms/step - loss: 106.1874 - val_loss: 81.0238
# Epoch 189/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.4599 - val_loss: 79.5214
# Epoch 190/200
# 32/32 [==============================] - 0s 2ms/step - loss: 104.9017 - val_loss: 80.4437
# Epoch 191/200
# 32/32 [==============================] - 0s 2ms/step - loss: 106.0711 - val_loss: 80.8032
# Epoch 192/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.7855 - val_loss: 81.5418
# Epoch 193/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.0684 - val_loss: 79.6693
# Epoch 194/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.7665 - val_loss: 79.7226
# Epoch 195/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.6357 - val_loss: 80.2608
# Epoch 196/200
# 32/32 [==============================] - 0s 2ms/step - loss: 106.9489 - val_loss: 80.2113
# Epoch 197/200
# 32/32 [==============================] - 0s 2ms/step - loss: 106.2759 - val_loss: 79.5379
# Epoch 198/200
# 32/32 [==============================] - 0s 2ms/step - loss: 107.0683 - val_loss: 81.1930
# Epoch 199/200
# 32/32 [==============================] - 0s 2ms/step - loss: 104.6383 - val_loss: 79.7788
# Epoch 200/200
# 32/32 [==============================] - 0s 2ms/step - loss: 105.1040 - val_loss: 79.6559

# %% [markdown]
# ## Model evaluation

# %%
# model.evaluate(x_test, y_test)
loss = model.evaluate(x_test, y_test)

# 繪製訓練歷史
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()
plt.show()
# Out:
# 1/1 [==============================] - 0s 79ms/step - loss: 114.2778

# %%
def plot_scatter (x, y, title, x_label, y_label,n):
    # plt.subplot(2, 2, n);
    plt.figure(figsize=(5, 5));
    plt.plot(x, x, color="blue", label="d")
    plt.scatter(x, y, marker="x", color="red")
    # plt.axis((0,210, 0,210))
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.show()

y_pred = model.predict(x_test)
plot_scatter(y_test, y_pred, "Testing set", "True value", "Pred. value",1)

y_pred = model.predict(x_train)
plot_scatter(y_train, y_pred, "Training set", "True value", "Pred. value",2)
# Out:
# 1/1 [==============================] - 0s 303ms/step
# 3/3 [==============================] - 0s 5ms/step

# %%
y_pred = model.predict(x_train)
plt.scatter(x_train, y_train, color='red', label='Actual values')
plt.scatter(x_train, y_pred, color='blue', marker='x', label='Predicted values')
plt.title('training set')
plt.legend()
plt.show()


y_pred = model.predict(x_test)
plt.scatter(x_test, y_test, color='red', label='Actual values')
plt.scatter(x_test, y_pred, color='blue', marker='x', label='Predicted values')
plt.title('testing set')
plt.legend()
plt.show()
# Out:
# 3/3 [==============================] - 0s 998us/step
# 1/1 [==============================] - 0s 18ms/step

# %% [markdown]
# ### Exercise : Please try to write R2 and Pearson correlation function for evaluating the training model

# %% [markdown]
# ### Coefficient of determination, denoted R2
# R2值衡量的是模型解釋的"變異"量相對於總變異量的比例。R2=1意味著模型完美地擬合了數據，能夠解釋所有的變異性；而R2=0代表著模型沒有解釋任何變異量，即它未能捕捉到y和y^之間的任何關係，意味著線性模型沒有提供超越基線模型（即常數模型，這個模型預測的 y 值對於所有觀察值都是 y 的平均值）的預測能力預測能力
#
# ![image.png](attachment:a916d88a-0f91-4fce-ab6d-76a38a2df566.png)
#
# Reference :
#
# https://en.wikipedia.org/wiki/Coefficient_of_determination
#
# https://www.ncl.ac.uk/webtemplate/ask-assets/external/maths-resources/statistics/regression-and-correlation/coefficient-of-determination-r-squared.html

# %%
from sklearn.metrics import r2_score
y_pred = np.squeeze(y_pred)
r2 = r2_score(y_pred,y_test)
print(r2)
# Out:
# 0.861573236052766

# %% [markdown]
# ## Pearson correlation function
# #### The Pearson correlation measures the strength of the linear relationship between two variables. It has a value between -1 to 1, with a value of -1 meaning a total negative linear correlation, 0 being no correlation, and + 1 meaning a total positive correlation.
#
# ![image.png](attachment:891bbceb-b815-4fd3-af18-067c0046a1a3.png)

# %% [markdown]
# 餘弦相似度的定義是兩個向量的點積除以這兩個向量模的乘積：
#
# ![image.png](attachment:533369cc-d3bb-4647-b383-0cd3fcd26886.png)
# ​

# %%
>>> from sklearn.datasets import make_regression
>>> from sklearn.feature_selection import r_regression

y_pred = model.predict(x_test)
Pearson_test = r_regression(y_test.reshape(-1,1),y_pred.ravel())
y_pred = model.predict(x_train)
Pearson_train = r_regression(y_train.reshape(-1,1),y_pred2.ravel())

print(Pearson_test,Pearson_train)
# Out:
# 1/1 [==============================] - 0s 15ms/step
# 3/3 [==============================] - 0s 997us/step
# [0.94535959] [0.9477322]
