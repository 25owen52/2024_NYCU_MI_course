# %% [markdown]
# ## Data Preparation

# %%
# install scikit-learn, tensorflow, pandas, matplotlib, numpy
# Out:
# 'conda' 不是內部或外部命令、可執行的程式或批次檔。

# %%
import pandas as pd

output_path = './F_Energy.csv'
path = output_path
df = pd.read_csv(output_path)
display(df.head())
# Out:
#   Pretty Formula   Density      Energy  Energy_per_Atom      Volume  \
# 0          B13C2  2.438648 -106.358032        -7.090535  112.056191
# 1           SiB3  2.449974 -204.992906        -6.406028  328.145035
# 2           SnB6  4.110240  -42.852113        -6.121730   74.164800
# 3           B6Pb  6.003820  -42.968600        -6.138371   75.248129
# 4             BN  3.302143  -68.876677        -8.609585   49.920018
#
#    Formation_Energy_per_Atom  Band Gap
# 0                  -0.072416    0.0089
# 1                  -0.040804    1.4083
# 2                   0.175492    0.7527
# 3                   0.114862    0.9209
# 4                  -1.294085    4.7885

# %%
df.info()
df.describe(include='all').round(2)

#round 函数在 Python（包括 Pandas 库中）的功能是对浮点数进行四舍五入到给定的精度。
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Pretty Formula             194 non-null    object
#  1   Density                    194 non-null    float64
#  2   Energy                     194 non-null    float64
#  3   Energy_per_Atom            194 non-null    float64
#  4   Volume                     194 non-null    float64
#  5   Formation_Energy_per_Atom  194 non-null    float64
#  6   Band Gap                   194 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 10.7+ KB
#        Pretty Formula  Density  Energy  Energy_per_Atom   Volume  \
# count             194   194.00  194.00           194.00   194.00
# unique            194      NaN     NaN              NaN      NaN
# top             B13C2      NaN     NaN              NaN      NaN
# freq                1      NaN     NaN              NaN      NaN
# mean              NaN     4.01 -102.56            -4.38   617.60
# std               NaN     1.84  134.24             1.50   867.71
# min               NaN     0.14 -787.96            -8.61    27.98
# 25%               NaN     2.60 -117.10            -5.29   147.24
# 50%               NaN     3.85  -54.00            -4.17   334.98
# 75%               NaN     5.07  -24.22            -3.18   720.48
# max               NaN     9.90   -4.03            -1.34  5834.92
#
#         Formation_Energy_per_Atom  Band Gap
# count                      194.00    194.00
# unique                        NaN       NaN
# top                           NaN       NaN
# freq                          NaN       NaN
# mean                        -0.65      1.96
# std                          0.94      1.54
# min                         -3.89      0.00
# 25%                         -1.12      0.80
# 50%                         -0.44      1.74
# 75%                         -0.07      2.85
# max                          1.88      7.72

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

y= df['Formation_Energy_per_Atom']
x= df.drop(columns=['Energy','Formation_Energy_per_Atom','Volume','Pretty Formula'])
display(x.head(5))
# print(set(x), set(y))

# splitting dataset to training set and testing set 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=20)
# Out:
#     Density  Energy_per_Atom  Band Gap
# 0  2.438648        -7.090535    0.0089
# 1  2.449974        -6.406028    1.4083
# 2  4.110240        -6.121730    0.7527
# 3  6.003820        -6.138371    0.9209
# 4  3.302143        -8.609585    4.7885

# %% [markdown]
# ##  data visualization

# %%
import matplotlib.pyplot as plt
plt.scatter(x_train['Density'], y_train, color='blue', label='Training data')
plt.scatter(x_test['Density'], y_test, color='red', label='Testing data')
plt.legend()
plt.show()

# %%
# Visualizing data before and after scaling with a pair plot
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 8));
sns.pairplot(data=df)
plt.suptitle('Pair Plot of Diabetes Dataset Before and After Scaling', y=1.02, fontsize=18);
plt.show();
# Out:
# C:\Users\Owen Yu\anaconda3\envs\Ai\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Owen Yu\anaconda3\envs\Ai\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Owen Yu\anaconda3\envs\Ai\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Owen Yu\anaconda3\envs\Ai\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Owen Yu\anaconda3\envs\Ai\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Owen Yu\anaconda3\envs\Ai\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## ==================================================================================================================
# ##　Data scaling
# https://www.cupoy.com/collection/0000018008CD5D70000000046375706F795F72656C656173654355/00000181709BCC8F000000056375706F795F72656C656173654349
# https://medium.com/@hhuseyincosgun/which-data-scaling-technique-should-i-use-a1615292061e
#
# Normalization (MinMaxScaler) :
# <br>
# <img src="https://miro.medium.com/v2/resize:fit:996/format:webp/1*gxth9npBXCrHDYbw9XJGrQ.png" width="20%" height="auto">
# <br>
#
# Standardization (Z-Score Standardization) : uses mean and standard deviation
# <br>
# <img src="https://miro.medium.com/v2/resize:fit:1400/format:webp/1*mViMXFWPqg7Vg2WwjaoKVQ.png" width="300" height="auto">
# <br>
#
# RobustScaler : uses median and interquartile range (IQR) instead
# <br>
# <img src="https://miro.medium.com/v2/resize:fit:1348/format:webp/1*uoQxqnwptSNabGU_JL3oPA.png" width="30%" height="auto">
# <br>
#
#
# <img src="https://miro.medium.com/v2/resize:fit:1400/format:webp/1*y0esOCH8O2NV1c_8iY3ouA.png" width="1200" height="auto">
# <br>
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/1/1a/Boxplot_vs_PDF.svg/440px-Boxplot_vs_PDF.svg.png" width="600" height="auto">
# <br>
# InterQuartile Range (四分位距 = 第三四分位數 - 第一四分位數) :
#
# [link to wiki](https://zh.wikipedia.org/zh-tw/%E5%9B%9B%E5%88%86%E4%BD%8D%E6%95%B0)
# <br>
#
# ### 中位數的重要性和應用 :
# 中位數是描述數據集中趨勢的一個非常有用的統計量，特別是當數據集中包含異常值（極端值）時。與平均值相比，中位數不易受到極端值的影響，因此在有異常值的數據集中提供了更穩定的“中心”測量。例如，在房價分析、收入分析等領域，使用中位數可以提供比平均值更真實的市場情況反映，因為這些領域常常受到極高或極低數據點的影響。

# %% [markdown]
# ## Exercise : try to use Standardization and Normalization to scale the training data

# %% [markdown]
# ## Build ANN model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# model = Sequential([
    # Dense(1, input_shape=(1,), activation='linear')
#     Dense(5, input_shape=(x.shape[1],), activation='linear')
# ])

model = Sequential([
    Dense(5, input_shape=(x.shape[1],), activation='relu'),
    Dense(3, activation='relu'),
    Dense(1, activation='linear')
])

# Sequential.help

model.compile(optimizer=Adam(learning_rate=0.005), loss='mse')

# %% [markdown]
# ## Training ANN model

# %%
from tensorflow.keras.callbacks import EarlyStopping

# early_stop = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# history = model.fit(x_train, y_train, validation_split=0.2, epochs=200, batch_size=2)
history = model.fit(x_scaled, y_train, validation_split=0.2, epochs=200, batch_size=2)
# Out:
# Epoch 1/200
# 62/62 [==============================] - 1s 6ms/step - loss: 0.9234 - val_loss: 1.2117
# Epoch 2/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.6907 - val_loss: 0.9865
# Epoch 3/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5986 - val_loss: 0.8572
# Epoch 4/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5374 - val_loss: 0.7159
# Epoch 5/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.5215 - val_loss: 0.6445
# Epoch 6/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4928 - val_loss: 0.6054
# Epoch 7/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.4741 - val_loss: 0.5850
# Epoch 8/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4941 - val_loss: 0.5602
# Epoch 9/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4757 - val_loss: 0.5692
# Epoch 10/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4678 - val_loss: 0.5309
# Epoch 11/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4651 - val_loss: 0.6185
# Epoch 12/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4687 - val_loss: 0.5415
# Epoch 13/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4586 - val_loss: 0.5503
# Epoch 14/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4497 - val_loss: 0.5050
# Epoch 15/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4307 - val_loss: 0.4684
# Epoch 16/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4382 - val_loss: 0.4934
# Epoch 17/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4174 - val_loss: 0.4941
# Epoch 18/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4131 - val_loss: 0.5601
# Epoch 19/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4038 - val_loss: 0.4579
# Epoch 20/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4063 - val_loss: 0.7024
# Epoch 21/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4122 - val_loss: 0.4803
# Epoch 22/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4011 - val_loss: 0.4496
# Epoch 23/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3959 - val_loss: 0.4973
# Epoch 24/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4555 - val_loss: 0.5726
# Epoch 25/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4108 - val_loss: 0.4787
# Epoch 26/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4102 - val_loss: 0.5463
# Epoch 27/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4022 - val_loss: 0.4453
# Epoch 28/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3862 - val_loss: 0.5081
# Epoch 29/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3774 - val_loss: 0.4567
# Epoch 30/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3927 - val_loss: 0.4786
# Epoch 31/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3919 - val_loss: 0.6152
# Epoch 32/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.4024 - val_loss: 0.4576
# Epoch 33/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3717 - val_loss: 0.4662
# Epoch 34/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3795 - val_loss: 0.4472
# Epoch 35/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3759 - val_loss: 0.4663
# Epoch 36/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.4062 - val_loss: 0.4902
# Epoch 37/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3633 - val_loss: 0.4412
# Epoch 38/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3604 - val_loss: 0.4626
# Epoch 39/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3625 - val_loss: 0.4567
# Epoch 40/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3795 - val_loss: 0.4866
# Epoch 41/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3700 - val_loss: 0.4372
# Epoch 42/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3751 - val_loss: 0.4644
# Epoch 43/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3552 - val_loss: 0.4791
# Epoch 44/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3776 - val_loss: 0.4930
# Epoch 45/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3657 - val_loss: 0.4874
# Epoch 46/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3667 - val_loss: 0.4508
# Epoch 47/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3662 - val_loss: 0.5061
# Epoch 48/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3538 - val_loss: 0.4514
# Epoch 49/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3419 - val_loss: 0.5090
# Epoch 50/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3564 - val_loss: 0.4352
# Epoch 51/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3522 - val_loss: 0.4809
# Epoch 52/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3599 - val_loss: 0.4677
# Epoch 53/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3531 - val_loss: 0.4367
# Epoch 54/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3401 - val_loss: 0.4280
# Epoch 55/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3387 - val_loss: 0.4925
# Epoch 56/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3348 - val_loss: 0.4646
# Epoch 57/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3509 - val_loss: 0.5382
# Epoch 58/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3758 - val_loss: 0.4755
# Epoch 59/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3412 - val_loss: 0.4654
# Epoch 60/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3406 - val_loss: 0.4769
# Epoch 61/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3273 - val_loss: 0.4396
# Epoch 62/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3535 - val_loss: 0.4543
# Epoch 63/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3424 - val_loss: 0.4488
# Epoch 64/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3331 - val_loss: 0.4466
# Epoch 65/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3385 - val_loss: 0.4608
# Epoch 66/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3541 - val_loss: 0.4623
# Epoch 67/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3363 - val_loss: 0.4559
# Epoch 68/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3348 - val_loss: 0.4753
# Epoch 69/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3365 - val_loss: 0.4424
# Epoch 70/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3333 - val_loss: 0.4636
# Epoch 71/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3314 - val_loss: 0.4710
# Epoch 72/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3446 - val_loss: 0.4923
# Epoch 73/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3387 - val_loss: 0.4513
# Epoch 74/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3464 - val_loss: 0.4648
# Epoch 75/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3489 - val_loss: 0.4958
# Epoch 76/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3402 - val_loss: 0.4532
# Epoch 77/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3385 - val_loss: 0.4809
# Epoch 78/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3489 - val_loss: 0.4691
# Epoch 79/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3465 - val_loss: 0.4485
# Epoch 80/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3323 - val_loss: 0.4789
# Epoch 81/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3674 - val_loss: 0.4353
# Epoch 82/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3317 - val_loss: 0.4839
# Epoch 83/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3417 - val_loss: 0.4697
# Epoch 84/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3254 - val_loss: 0.4651
# Epoch 85/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3270 - val_loss: 0.4921
# Epoch 86/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3182 - val_loss: 0.4849
# Epoch 87/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3501 - val_loss: 0.4716
# Epoch 88/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3368 - val_loss: 0.5016
# Epoch 89/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3315 - val_loss: 0.4864
# Epoch 90/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3173 - val_loss: 0.4792
# Epoch 91/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3419 - val_loss: 0.4755
# Epoch 92/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3201 - val_loss: 0.4641
# Epoch 93/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3506 - val_loss: 0.4600
# Epoch 94/200
# 62/62 [==============================] - 1s 13ms/step - loss: 0.3200 - val_loss: 0.5089
# Epoch 95/200
# 62/62 [==============================] - 0s 7ms/step - loss: 0.3605 - val_loss: 0.5014
# Epoch 96/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.3341 - val_loss: 0.4758
# Epoch 97/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.3324 - val_loss: 0.4797
# Epoch 98/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.3362 - val_loss: 0.4824
# Epoch 99/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3239 - val_loss: 0.4670
# Epoch 100/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3399 - val_loss: 0.4831
# Epoch 101/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3381 - val_loss: 0.4773
# Epoch 102/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3262 - val_loss: 0.5255
# Epoch 103/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3476 - val_loss: 0.4825
# Epoch 104/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3285 - val_loss: 0.5384
# Epoch 105/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3369 - val_loss: 0.4489
# Epoch 106/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3295 - val_loss: 0.4864
# Epoch 107/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3279 - val_loss: 0.4663
# Epoch 108/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3551 - val_loss: 0.5003
# Epoch 109/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3397 - val_loss: 0.4742
# Epoch 110/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3356 - val_loss: 0.5406
# Epoch 111/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3394 - val_loss: 0.4723
# Epoch 112/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3358 - val_loss: 0.4636
# Epoch 113/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3315 - val_loss: 0.4691
# Epoch 114/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3404 - val_loss: 0.4912
# Epoch 115/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3324 - val_loss: 0.4926
# Epoch 116/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3293 - val_loss: 0.5216
# Epoch 117/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3313 - val_loss: 0.4895
# Epoch 118/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3221 - val_loss: 0.5033
# Epoch 119/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3181 - val_loss: 0.4563
# Epoch 120/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3220 - val_loss: 0.4785
# Epoch 121/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3246 - val_loss: 0.4677
# Epoch 122/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3174 - val_loss: 0.4868
# Epoch 123/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3315 - val_loss: 0.4658
# Epoch 124/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3262 - val_loss: 0.5099
# Epoch 125/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3319 - val_loss: 0.5223
# Epoch 126/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3250 - val_loss: 0.4788
# Epoch 127/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3211 - val_loss: 0.5179
# Epoch 128/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3285 - val_loss: 0.5358
# Epoch 129/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3259 - val_loss: 0.5413
# Epoch 130/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3407 - val_loss: 0.5168
# Epoch 131/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3198 - val_loss: 0.5038
# Epoch 132/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3296 - val_loss: 0.5462
# Epoch 133/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3393 - val_loss: 0.5398
# Epoch 134/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3252 - val_loss: 0.5245
# Epoch 135/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3298 - val_loss: 0.5286
# Epoch 136/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3458 - val_loss: 0.4751
# Epoch 137/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3233 - val_loss: 0.4981
# Epoch 138/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3368 - val_loss: 0.5357
# Epoch 139/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3239 - val_loss: 0.5052
# Epoch 140/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3240 - val_loss: 0.5077
# Epoch 141/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3260 - val_loss: 0.5124
# Epoch 142/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3324 - val_loss: 0.4997
# Epoch 143/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3269 - val_loss: 0.5516
# Epoch 144/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3440 - val_loss: 0.5271
# Epoch 145/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3236 - val_loss: 0.5293
# Epoch 146/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3249 - val_loss: 0.4971
# Epoch 147/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.3210 - val_loss: 0.5295
# Epoch 148/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3282 - val_loss: 0.4995
# Epoch 149/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.3294 - val_loss: 0.5365
# Epoch 150/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.3249 - val_loss: 0.5215
# Epoch 151/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.3188 - val_loss: 0.4878
# Epoch 152/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3274 - val_loss: 0.5182
# Epoch 153/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3382 - val_loss: 0.5293
# Epoch 154/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3150 - val_loss: 0.5521
# Epoch 155/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3310 - val_loss: 0.5347
# Epoch 156/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3231 - val_loss: 0.5277
# Epoch 157/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3176 - val_loss: 0.5137
# Epoch 158/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3237 - val_loss: 0.5060
# Epoch 159/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3161 - val_loss: 0.5813
# Epoch 160/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3285 - val_loss: 0.5182
# Epoch 161/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3242 - val_loss: 0.5412
# Epoch 162/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3186 - val_loss: 0.5616
# Epoch 163/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3116 - val_loss: 0.5478
# Epoch 164/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3554 - val_loss: 0.5352
# Epoch 165/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3366 - val_loss: 0.5103
# Epoch 166/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3178 - val_loss: 0.5026
# Epoch 167/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3171 - val_loss: 0.4964
# Epoch 168/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3265 - val_loss: 0.5123
# Epoch 169/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3179 - val_loss: 0.5233
# Epoch 170/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3520 - val_loss: 0.5584
# Epoch 171/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3127 - val_loss: 0.5035
# Epoch 172/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3101 - val_loss: 0.5053
# Epoch 173/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3359 - val_loss: 0.5137
# Epoch 174/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3342 - val_loss: 0.5201
# Epoch 175/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3278 - val_loss: 0.5115
# Epoch 176/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3227 - val_loss: 0.5104
# Epoch 177/200
# 62/62 [==============================] - 0s 6ms/step - loss: 0.3232 - val_loss: 0.5088
# Epoch 178/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3192 - val_loss: 0.5228
# Epoch 179/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3183 - val_loss: 0.5324
# Epoch 180/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3382 - val_loss: 0.5283
# Epoch 181/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3209 - val_loss: 0.5331
# Epoch 182/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3321 - val_loss: 0.5395
# Epoch 183/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3265 - val_loss: 0.5113
# Epoch 184/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3205 - val_loss: 0.5007
# Epoch 185/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3227 - val_loss: 0.5317
# Epoch 186/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3229 - val_loss: 0.5312
# Epoch 187/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3087 - val_loss: 0.5180
# Epoch 188/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3092 - val_loss: 0.5384
# Epoch 189/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3242 - val_loss: 0.5599
# Epoch 190/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3304 - val_loss: 0.5449
# Epoch 191/200
# 62/62 [==============================] - 0s 3ms/step - loss: 0.3205 - val_loss: 0.5170
# Epoch 192/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3122 - val_loss: 0.5177
# Epoch 193/200
# 62/62 [==============================] - 0s 5ms/step - loss: 0.3205 - val_loss: 0.5127
# Epoch 194/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3070 - val_loss: 0.5623
# Epoch 195/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3537 - val_loss: 0.5332
# Epoch 196/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3219 - val_loss: 0.5292
# Epoch 197/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3322 - val_loss: 0.5392
# Epoch 198/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3143 - val_loss: 0.5250
# Epoch 199/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3088 - val_loss: 0.5167
# Epoch 200/200
# 62/62 [==============================] - 0s 4ms/step - loss: 0.3096 - val_loss: 0.5223

# %% [markdown]
# ## Model evaluation

# %%
history.history['loss'][:10]
# Out:
# [0.9233982563018799,
#  0.6906872987747192,
#  0.5985997319221497,
#  0.5373627543449402,
#  0.5214613676071167,
#  0.49283137917518616,
#  0.47413524985313416,
#  0.4941326975822449,
#  0.47570425271987915,
#  0.46778273582458496]

# %%
# model.evaluate(x_test, y_test)
loss = model.evaluate(x_test, y_test)

# 绘制训练历史
plt.plot(history.history['loss'][10:], label='Training loss')
plt.plot(history.history['val_loss'][10:], label='Validation loss')
plt.legend()
plt.show()
# Out:
# 2/2 [==============================] - 0s 4ms/step - loss: 1.1507

# %% [markdown]
# ## Error inside
# ## Hint : scaling the data before prediction

# %%
def plot_scatter (x, y, title, x_label, y_label,n):
    # plt.subplot(2, 2, n);
    plt.figure(figsize=(5, 5));
    plt.plot(x, x, color="blue", label="d")
    plt.scatter(x, y, marker="x", color="red")
    # plt.axis((0,210, 0,210))
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.show()
    

y_pred = model.predict(x_test)
plot_scatter(y_test, y_pred, "Testing set", "True value", "Pred. value",1)

y_pred = model.predict(x_train)
plot_scatter(y_train, y_pred, "Training set", "True value", "Pred. value",2)
# Out:
# 2/2 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 3ms/step

# %% [markdown]
# ## Error inside
# ## Hint : scaling the data before prediction

# %%
y_pred = model.predict(x_train)
plt.scatter(x_train['Density'], y_train, color='red', label='Actual values')
plt.scatter(x_train['Density'], y_pred, color='blue', marker='x', label='Predicted values')
plt.title('training set')
plt.legend()
plt.show()


y_pred = model.predict(x_test)
plt.scatter(x_test['Density'], y_test, color='red', label='Actual values')
plt.scatter(x_test['Density'], y_pred, color='blue', marker='x', label='Predicted values')
plt.title('testing set')
plt.legend()
plt.show()
# Out:
# 5/5 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 5ms/step

# %% [markdown]
# ## Error inside
# ## Hint : scaling the data before prediction

# %%
## Coefficient of determination, denoted R2
from sklearn.metrics import r2_score
y_pred = model.predict(x_test)
r2_test = r2_score(y_test, y_pred)

y_pred = model.predict(x_train)
r2_train = r2_score(y_train, y_pred)

print(r2_train, r2_test)
# Out:
# 2/2 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 2ms/step
# -0.2401081388470787 -0.26571370296064356

# %%
## Pearson correlation function
from sklearn.datasets import make_regression
from sklearn.feature_selection import r_regression

y_pred = model.predict(x_test)
psc_test = r_regression(y_test.to_numpy().reshape(-1, 1) , y_pred.ravel())[0]
y_pred = model.predict(x_train)
psc_train = r_regression(y_train.to_numpy().reshape(-1, 1), y_pred.ravel())[0]
print(psc_train, psc_test)
# Out:
# 2/2 [==============================] - 0s 4ms/step
# 5/5 [==============================] - 0s 3ms/step
# 0.26317809109081114 0.4475416492147637
